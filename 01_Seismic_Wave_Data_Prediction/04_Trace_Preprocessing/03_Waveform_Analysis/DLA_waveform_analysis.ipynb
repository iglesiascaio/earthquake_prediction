# %%
import os
import logging
from obspy import read, Stream, UTCDateTime
import numpy as np
from obspy import Trace

station = 'DLA'
year = '2024'
channels = ['BHN','BHE','BHZ']

for channel in channels:
    file_path = f'/home/gridsan/mknuth/01_Seismic_Wave_Data_Prediction/01_Data/01_Seismic_Wave_Data/{year}/{station}/{channel}/{station}_{channel}_{year}-01-09.mseed'
    stream = read(file_path)
    print(stream)
# Out:
# 1 Trace(s) in Stream:
# CI.DLA..BHN | 2024-01-09T00:00:00.000000Z - 2024-01-09T23:59:59.975000Z | 40.0 Hz, 3456000 samples
# 1 Trace(s) in Stream:
# CI.DLA..BHE | 2024-01-09T00:00:00.000000Z - 2024-01-09T23:59:59.975000Z | 40.0 Hz, 3456000 samples
# 1 Trace(s) in Stream:
# CI.DLA..BHZ | 2024-01-09T00:00:00.000000Z - 2024-01-09T23:59:59.975000Z | 40.0 Hz, 3456000 samples

# %%
stream[0].stats
# Out:
#          network: CI
#          station: DLA
#         location:
#          channel: BHZ
#        starttime: 2024-01-09T00:00:00.000000Z
#          endtime: 2024-01-09T23:59:59.975000Z
#    sampling_rate: 40.0
#            delta: 0.025
#             npts: 3456000
#            calib: 1.0
#          _format: MSEED
#            mseed: AttribDict({'dataquality': 'D', 'number_of_records': 16892, 'encoding': 'STEIM2', 'byteorder': '>', 'record_length': 512, 'filesize': 8648704})

# %%
import os
import logging
from obspy import read, Stream, UTCDateTime
import numpy as np
from obspy import Trace

def format_duration(duration):
    """Convert duration from seconds to hours:minutes format."""
    hours = int(duration // 3600)
    minutes = int((duration % 3600) // 60)
    return f"{hours:02d}:{minutes:02d}"

def save_processed_trace(trace, original_path):
    """Save the processed trace to a new file with '_processed' appended to the original name."""
    directory, filename = os.path.split(original_path)
    name, ext = os.path.splitext(filename)
    new_filename = f"{name}_processed{ext}"
    new_path = os.path.join(directory, new_filename)
    trace.write(new_path, format='MSEED')
    logging.info(f"Saved processed trace to: {new_path}")

def process_waveform(file_path):
    try:
        stream = read(file_path)
        #print(f"Number of traces: {len(stream)}")
        if len(stream) > 1:
            print(stream)
        
        
        stream.merge(method=1, fill_value=0)
        duration = stream[0].stats.endtime - stream[0].stats.starttime
        duration_str = format_duration(duration)
        logging.info(f"Stream goes from {stream[0].stats.starttime} to {stream[0].stats.endtime} (duration: {duration_str})")
        #print(f"Stream goes from {stream[0].stats.starttime} to {stream[0].stats.endtime} (duration: {duration_str})")

        # Save the processed trace
        save_processed_trace(stream[0], file_path)

    except Exception as e:
        logging.error(f"Error processing file {stream[0]}: {str(e)}")
        print(f"Error processing file {stream[0]}: {str(e)}")



base_dir = f"/home/gridsan/mknuth/01_Seismic_Wave_Data_Prediction/01_Data/01_Seismic_Wave_Data/{year}/{station}"

logging.basicConfig(filename=f"{year}_{station}_trace_preprocessing.log", level=logging.INFO, format='%(asctime)s - %(message)s', filemode='w')
# Base directory to start searching


print(f'processing year {year}')
# Collect all mseed files recursively in a list
file_list = []

for root, dirs, files in os.walk(base_dir):
    for file in files:
        if file.endswith(".mseed"):
            file_path = os.path.join(root, file)
            file_list.append(file_path)

# Sort the list of files alphabetically
file_list.sort()
print(f"In total {len(file_list)} files")

# Process each file that has not been processed yet, total 1095 in 2021
for file_path in file_list:
    # Skip already processed files
    if "_processed" in os.path.basename(file_path):
        logging.info(f"Skipping already processed file: {os.path.basename(file_path)}")
        continue
    
    #print(f"Processing file {file_path}")
    logging.info(f"Processing file {os.path.basename(file_path)}")
    process_waveform(file_path)
# Out:
# processing year 2024
# In total 1098 files
# 3 Trace(s) in Stream:
# CI.DLA..BHE | 2024-03-25T00:00:00.000000Z - 2024-03-25T21:14:50.500000Z | 40.0 Hz, 3059621 samples
# CI.DLA..BHE | 2024-03-25T21:29:31.525000Z - 2024-03-25T21:31:24.850000Z | 40.0 Hz, 4534 samples
# CI.DLA..BHE | 2024-03-25T21:56:25.525000Z - 2024-03-25T23:59:59.975000Z | 40.0 Hz, 296579 samples
# 2 Trace(s) in Stream:
# CI.DLA..BHE | 2024-03-26T00:00:00.000000Z - 2024-03-26T20:31:04.500000Z | 40.0 Hz, 2954581 samples
# CI.DLA..BHE | 2024-03-26T20:31:08.725000Z - 2024-03-26T23:59:59.975000Z | 40.0 Hz, 501251 samples
# 2 Trace(s) in Stream:
# CI.DLA..BHE | 2024-04-24T00:00:00.000000Z - 2024-04-24T16:52:18.500000Z | 40.0 Hz, 2429541 samples
# CI.DLA..BHE | 2024-04-24T16:52:21.975000Z - 2024-04-24T23:59:59.975000Z | 40.0 Hz, 1026321 samples
# 2 Trace(s) in Stream:
# CI.DLA..BHE | 2024-04-29T00:00:00.000000Z - 2024-04-29T11:59:54.450000Z | 40.0 Hz, 1727779 samples
# CI.DLA..BHE | 2024-04-29T11:59:59.625000Z - 2024-04-29T23:59:59.975000Z | 40.0 Hz, 1728015 samples
# 188 Trace(s) in Stream:
#
# CI.DLA..BHE | 2024-05-09T00:00:00.000000Z - 2024-05-09T00:11:15.500000Z | 40.0 Hz, 27021 samples
# ...
# (186 other traces)
# ...
# CI.DLA..BHE | 2024-05-09T17:39:09.475000Z - 2024-05-09T23:59:59.975000Z | 40.0 Hz, 914021 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 2 Trace(s) in Stream:
# CI.DLA..BHE | 2024-07-02T00:00:00.000000Z - 2024-07-02T21:54:52.500000Z | 40.0 Hz, 3155701 samples
# CI.DLA..BHE | 2024-07-02T21:54:55.475000Z - 2024-07-02T23:59:59.975000Z | 40.0 Hz, 300181 samples
# 76 Trace(s) in Stream:
#
# CI.DLA..BHE | 2024-08-02T02:25:38.654200Z - 2024-08-02T03:32:33.929200Z | 40.0 Hz, 160612 samples
# ...
# (74 other traces)
# ...
# CI.DLA..BHE | 2024-08-02T19:17:22.004200Z - 2024-08-02T23:59:59.979200Z | 40.0 Hz, 678320 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 2 Trace(s) in Stream:
# CI.DLA..BHE | 2024-08-18T00:00:00.004200Z - 2024-08-18T04:15:00.629200Z | 40.0 Hz, 612026 samples
# CI.DLA..BHE | 2024-08-18T04:15:03.804200Z - 2024-08-18T23:59:59.979200Z | 40.0 Hz, 2843848 samples
# 2 Trace(s) in Stream:
# CI.DLA..BHE | 2024-11-26T00:00:00.004200Z - 2024-11-26T19:02:52.629200Z | 40.0 Hz, 2742906 samples
# CI.DLA..BHE | 2024-11-26T19:02:54.404200Z - 2024-11-26T23:59:59.979200Z | 40.0 Hz, 713024 samples
# 2 Trace(s) in Stream:
# CI.DLA..BHE | 2024-12-13T00:00:00.004200Z - 2024-12-13T23:22:41.629200Z | 40.0 Hz, 3366466 samples
# CI.DLA..BHE | 2024-12-13T23:22:42.554200Z - 2024-12-13T23:59:59.979200Z | 40.0 Hz, 89498 samples
# 3 Trace(s) in Stream:
# CI.DLA..BHN | 2024-03-25T00:00:00.000000Z - 2024-03-25T21:14:50.500000Z | 40.0 Hz, 3059621 samples
# CI.DLA..BHN | 2024-03-25T21:29:31.525000Z - 2024-03-25T21:31:24.800000Z | 40.0 Hz, 4532 samples
# CI.DLA..BHN | 2024-03-25T21:56:25.525000Z - 2024-03-25T23:59:59.975000Z | 40.0 Hz, 296579 samples
# 2 Trace(s) in Stream:
# CI.DLA..BHN | 2024-03-26T00:00:00.000000Z - 2024-03-26T20:31:04.500000Z | 40.0 Hz, 2954581 samples
# CI.DLA..BHN | 2024-03-26T20:31:05.225000Z - 2024-03-26T23:59:59.975000Z | 40.0 Hz, 501391 samples
# 2 Trace(s) in Stream:
# CI.DLA..BHN | 2024-04-24T00:00:00.000000Z - 2024-04-24T16:52:18.500000Z | 40.0 Hz, 2429541 samples
# CI.DLA..BHN | 2024-04-24T16:52:22.875000Z - 2024-04-24T23:59:59.975000Z | 40.0 Hz, 1026285 samples
# 202 Trace(s) in Stream:
#
# CI.DLA..BHN | 2024-05-09T00:00:00.000000Z - 2024-05-09T00:03:17.725000Z | 40.0 Hz, 7910 samples
# ...
# (200 other traces)
# ...
# CI.DLA..BHN | 2024-05-09T17:39:09.125000Z - 2024-05-09T23:59:59.975000Z | 40.0 Hz, 914035 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 2 Trace(s) in Stream:
# CI.DLA..BHN | 2024-07-02T00:00:00.000000Z - 2024-07-02T21:54:52.500000Z | 40.0 Hz, 3155701 samples
# CI.DLA..BHN | 2024-07-02T21:54:55.775000Z - 2024-07-02T23:59:59.975000Z | 40.0 Hz, 300169 samples
# 75 Trace(s) in Stream:
#
# CI.DLA..BHN | 2024-08-02T02:25:38.654200Z - 2024-08-02T03:32:33.979200Z | 40.0 Hz, 160614 samples
# ...
# (73 other traces)
# ...
# CI.DLA..BHN | 2024-08-02T19:17:27.104200Z - 2024-08-02T23:59:59.979200Z | 40.0 Hz, 678116 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 2 Trace(s) in Stream:
# CI.DLA..BHN | 2024-08-18T00:00:00.004200Z - 2024-08-18T04:15:00.629200Z | 40.0 Hz, 612026 samples
# CI.DLA..BHN | 2024-08-18T04:15:03.804200Z - 2024-08-18T23:59:59.979200Z | 40.0 Hz, 2843848 samples
# 2 Trace(s) in Stream:
# CI.DLA..BHN | 2024-11-26T00:00:00.004200Z - 2024-11-26T19:02:52.629200Z | 40.0 Hz, 2742906 samples
# CI.DLA..BHN | 2024-11-26T19:02:56.554200Z - 2024-11-26T23:59:59.979200Z | 40.0 Hz, 712938 samples
# 2 Trace(s) in Stream:
# CI.DLA..BHN | 2024-12-13T00:00:00.004200Z - 2024-12-13T23:22:41.629200Z | 40.0 Hz, 3366466 samples
# CI.DLA..BHN | 2024-12-13T23:22:42.004200Z - 2024-12-13T23:59:59.979200Z | 40.0 Hz, 89520 samples
# 3 Trace(s) in Stream:
# CI.DLA..BHZ | 2024-03-25T00:00:00.000000Z - 2024-03-25T21:14:50.500000Z | 40.0 Hz, 3059621 samples
# CI.DLA..BHZ | 2024-03-25T21:29:31.525000Z - 2024-03-25T21:31:23.500000Z | 40.0 Hz, 4480 samples
# CI.DLA..BHZ | 2024-03-25T21:56:25.525000Z - 2024-03-25T23:59:59.975000Z | 40.0 Hz, 296579 samples
# 2 Trace(s) in Stream:
# CI.DLA..BHZ | 2024-03-26T00:00:00.000000Z - 2024-03-26T20:31:04.500000Z | 40.0 Hz, 2954581 samples
# CI.DLA..BHZ | 2024-03-26T20:31:06.075000Z - 2024-03-26T23:59:59.975000Z | 40.0 Hz, 501357 samples
# 2 Trace(s) in Stream:
# CI.DLA..BHZ | 2024-04-24T00:00:00.000000Z - 2024-04-24T16:52:18.500000Z | 40.0 Hz, 2429541 samples
# CI.DLA..BHZ | 2024-04-24T16:52:18.925000Z - 2024-04-24T23:59:59.975000Z | 40.0 Hz, 1026443 samples
# 183 Trace(s) in Stream:
#
# CI.DLA..BHZ | 2024-05-09T00:00:00.000000Z - 2024-05-09T00:09:23.550000Z | 40.0 Hz, 22543 samples
# ...
# (181 other traces)
# ...
# CI.DLA..BHZ | 2024-05-09T17:39:10.575000Z - 2024-05-09T23:59:59.975000Z | 40.0 Hz, 913977 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 2 Trace(s) in Stream:
# CI.DLA..BHZ | 2024-07-02T00:00:00.000000Z - 2024-07-02T21:54:52.500000Z | 40.0 Hz, 3155701 samples
# CI.DLA..BHZ | 2024-07-02T21:54:53.750000Z - 2024-07-02T23:59:59.975000Z | 40.0 Hz, 300250 samples
# 77 Trace(s) in Stream:
#
# CI.DLA..BHZ | 2024-08-02T02:25:38.654200Z - 2024-08-02T03:32:35.879200Z | 40.0 Hz, 160690 samples
# ...
# (75 other traces)
# ...
# CI.DLA..BHZ | 2024-08-02T19:17:24.254200Z - 2024-08-02T23:59:59.979200Z | 40.0 Hz, 678230 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 2 Trace(s) in Stream:
# CI.DLA..BHZ | 2024-08-18T00:00:00.004200Z - 2024-08-18T04:15:00.629200Z | 40.0 Hz, 612026 samples
# CI.DLA..BHZ | 2024-08-18T04:15:03.804200Z - 2024-08-18T23:59:59.979200Z | 40.0 Hz, 2843848 samples
# 2 Trace(s) in Stream:
# CI.DLA..BHZ | 2024-11-26T00:00:00.004200Z - 2024-11-26T19:02:52.629200Z | 40.0 Hz, 2742906 samples
# CI.DLA..BHZ | 2024-11-26T19:02:54.054200Z - 2024-11-26T23:59:59.979200Z | 40.0 Hz, 713038 samples
# 2 Trace(s) in Stream:
# CI.DLA..BHZ | 2024-12-13T00:00:00.004200Z - 2024-12-13T23:22:41.629200Z | 40.0 Hz, 3366466 samples
# CI.DLA..BHZ | 2024-12-13T23:22:45.554200Z - 2024-12-13T23:59:59.979200Z | 40.0 Hz, 89378 samples

# %%
station = 'BHP'
year = '2023'
channel = 'BHN' #'BHE','BHZ'


file_path = f'/home/gridsan/mknuth/01_Seismic_Wave_Data_Prediction/01_Data/01_Seismic_Wave_Data/{year}/{station}/{channel}/{station}_{channel}_{year}-07-23.mseed'
stream = read(file_path)
print(stream)
# Out:
# 33468 Trace(s) in Stream:
#
# CI.BHP..BHN | 2023-07-23T00:00:00.019536Z - 2023-07-23T00:00:04.419536Z | 40.0 Hz, 177 samples
# ...
# (33466 other traces)
# ...
# CI.BHP..BHN | 2023-07-23T23:59:59.894538Z - 2023-07-23T23:59:59.994538Z | 40.0 Hz, 5 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
