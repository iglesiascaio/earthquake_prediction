# %%
import os
import logging
from obspy import read, Stream, UTCDateTime
import numpy as np
from obspy import Trace

station = 'SYN'
year = '2024'
channels = ['BHN','BHE','BHZ']

for channel in channels:
    file_path = f'/home/gridsan/mknuth/01_Seismic_Wave_Data_Prediction/01_Data/01_Seismic_Wave_Data/{year}/{station}/{channel}/{station}_{channel}_{year}-01-01.mseed'
    stream = read(file_path)
    print(stream)
# Out:
# 34 Trace(s) in Stream:
#
# CI.SYN..BHN | 2024-01-01T00:00:00.019538Z - 2024-01-01T00:05:16.569538Z | 40.0 Hz, 12663 samples
# ...
# (32 other traces)
# ...
# CI.SYN..BHN | 2024-01-01T23:37:48.594541Z - 2024-01-01T23:55:11.569541Z | 40.0 Hz, 41720 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 34 Trace(s) in Stream:
#
# CI.SYN..BHE | 2024-01-01T00:00:00.019538Z - 2024-01-01T00:05:16.569538Z | 40.0 Hz, 12663 samples
# ...
# (32 other traces)
# ...
# CI.SYN..BHE | 2024-01-01T23:37:48.594541Z - 2024-01-01T23:55:11.569541Z | 40.0 Hz, 41720 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 34 Trace(s) in Stream:
#
# CI.SYN..BHZ | 2024-01-01T00:00:00.019538Z - 2024-01-01T00:05:16.569538Z | 40.0 Hz, 12663 samples
# ...
# (32 other traces)
# ...
# CI.SYN..BHZ | 2024-01-01T23:37:48.594541Z - 2024-01-01T23:55:11.569541Z | 40.0 Hz, 41720 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]

# %%
stream[0].stats
# Out:
#          network: CI
#          station: SYN
#         location:
#          channel: BHZ
#        starttime: 2024-01-01T00:00:00.019538Z
#          endtime: 2024-01-01T00:05:16.569538Z
#    sampling_rate: 40.0
#            delta: 0.025
#             npts: 12663
#            calib: 1.0
#          _format: MSEED
#            mseed: AttribDict({'dataquality': 'D', 'number_of_records': 35, 'encoding': 'STEIM2', 'byteorder': '>', 'record_length': 512, 'filesize': 4150784})

# %%
import os
import logging
from obspy import read, Stream, UTCDateTime
import numpy as np
from obspy import Trace

def format_duration(duration):
    """Convert duration from seconds to hours:minutes format."""
    hours = int(duration // 3600)
    minutes = int((duration % 3600) // 60)
    return f"{hours:02d}:{minutes:02d}"

def save_processed_trace(trace, original_path):
    """Save the processed trace to a new file with '_processed' appended to the original name."""
    directory, filename = os.path.split(original_path)
    name, ext = os.path.splitext(filename)
    new_filename = f"{name}_processed{ext}"
    new_path = os.path.join(directory, new_filename)
    trace.write(new_path, format='MSEED')
    logging.info(f"Saved processed trace to: {new_path}")

def process_waveform(file_path):
    try:
        stream = read(file_path)
        #print(f"Number of traces: {len(stream)}")
        if len(stream) > 1:
            print(stream)
        
        
        stream.merge(method=1, fill_value=0)
        duration = stream[0].stats.endtime - stream[0].stats.starttime
        duration_str = format_duration(duration)
        logging.info(f"Stream goes from {stream[0].stats.starttime} to {stream[0].stats.endtime} (duration: {duration_str})")
        #print(f"Stream goes from {stream[0].stats.starttime} to {stream[0].stats.endtime} (duration: {duration_str})")

        # Save the processed trace
        save_processed_trace(stream[0], file_path)

    except Exception as e:
        logging.error(f"Error processing file {stream[0]}: {str(e)}")
        print(f"Error processing file {stream[0]}: {str(e)}")



base_dir = f"/home/gridsan/mknuth/01_Seismic_Wave_Data_Prediction/01_Data/01_Seismic_Wave_Data/{year}/{station}"

logging.basicConfig(filename=f"{year}_{station}_trace_preprocessing.log", level=logging.INFO, format='%(asctime)s - %(message)s', filemode='w')
# Base directory to start searching


print(f'processing year {year}')
# Collect all mseed files recursively in a list
file_list = []

for root, dirs, files in os.walk(base_dir):
    for file in files:
        if file.endswith(".mseed"):
            file_path = os.path.join(root, file)
            file_list.append(file_path)

# Sort the list of files alphabetically
file_list.sort()
print(f"In total {len(file_list)} files")

# Process each file that has not been processed yet, total 1095 in 2021
for file_path in file_list:
    # Skip already processed files
    if "_processed" in os.path.basename(file_path):
        logging.info(f"Skipping already processed file: {os.path.basename(file_path)}")
        continue
    
    #print(f"Processing file {file_path}")
    logging.info(f"Processing file {os.path.basename(file_path)}")
    process_waveform(file_path)
# Out:
# processing year 2024
# In total 1098 files
# 34 Trace(s) in Stream:
#
# CI.SYN..BHE | 2024-01-01T00:00:00.019538Z - 2024-01-01T00:05:16.569538Z | 40.0 Hz, 12663 samples
# ...
# (32 other traces)
# ...
# CI.SYN..BHE | 2024-01-01T23:37:48.594541Z - 2024-01-01T23:55:11.569541Z | 40.0 Hz, 41720 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 47 Trace(s) in Stream:
#
# CI.SYN..BHE | 2024-01-02T00:01:23.594538Z - 2024-01-02T00:13:15.569538Z | 40.0 Hz, 28480 samples
# ...
# (45 other traces)
# ...
# CI.SYN..BHE | 2024-01-02T23:33:18.594541Z - 2024-01-02T23:59:59.994541Z | 40.0 Hz, 64057 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 33 Trace(s) in Stream:
#
# CI.SYN..BHE | 2024-01-03T00:00:00.019534Z - 2024-01-03T01:54:30.569534Z | 40.0 Hz, 274823 samples
# ...
# (31 other traces)
# ...
# CI.SYN..BHE | 2024-01-03T23:48:35.594538Z - 2024-01-03T23:59:59.994538Z | 40.0 Hz, 27377 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 38 Trace(s) in Stream:
#
# CI.SYN..BHE | 2024-01-04T00:00:00.019538Z - 2024-01-04T00:00:46.569538Z | 40.0 Hz, 1863 samples
# ...
# (36 other traces)
# ...
# CI.SYN..BHE | 2024-01-04T22:37:48.594541Z - 2024-01-04T23:59:59.994541Z | 40.0 Hz, 197257 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 45 Trace(s) in Stream:
#
# CI.SYN..BHE | 2024-01-05T00:00:00.019538Z - 2024-01-05T00:15:27.569538Z | 40.0 Hz, 37103 samples
# ...
# (43 other traces)
# ...
# CI.SYN..BHE | 2024-01-05T23:25:19.594539Z - 2024-01-05T23:59:59.994539Z | 40.0 Hz, 83217 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
#
samples
# ...
# (32 other traces)
# ...
# CI.SYN..BHE | 2024-01-19T23:35:18.594541Z - 2024-01-19T23:59:59.994541Z | 40.0 Hz, 59257 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 37 Trace(s) in Stream:
#
# CI.SYN..BHE | 2024-01-20T00:00:00.019533Z - 2024-01-20T00:06:46.569533Z | 40.0 Hz, 16263 samples
# ...
# (35 other traces)
# ...
# CI.SYN..BHE | 2024-01-20T23:54:19.594541Z - 2024-01-20T23:59:59.994541Z | 40.0 Hz, 13617 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 11 Trace(s) in Stream:
# CI.SYN..BHE | 2024-01-21T00:00:00.019908Z - 2024-01-21T00:15:12.569908Z | 40.0 Hz, 36503 samples
# CI.SYN..BHE | 2024-01-21T00:21:25.594538Z - 2024-01-21T00:53:40.569538Z | 40.0 Hz, 77400 samples
# CI.SYN..BHE | 2024-01-21T00:53:43.594541Z - 2024-01-21T05:58:10.569541Z | 40.0 Hz, 730680 samples
# CI.SYN..BHE | 2024-01-21T06:04:23.594538Z - 2024-01-21T06:18:40.569538Z | 40.0 Hz, 34280 samples
# CI.SYN..BHE | 2024-01-21T06:18:43.594541Z - 2024-01-21T10:29:59.569541Z | 40.0 Hz, 603040 samples
# CI.SYN..BHE | 2024-01-21T10:36:11.594538Z - 2024-01-21T10:48:16.569538Z | 40.0 Hz, 29000 samples
# CI.SYN..BHE | 2024-01-21T10:48:19.594541Z - 2024-01-21T13:41:14.569541Z | 40.0 Hz, 415000 samples
# CI.SYN..BHE | 2024-01-21T13:47:26.594538Z - 2024-01-21T14:00:15.569538Z | 40.0 Hz, 30760 samples
# CI.SYN..BHE | 2024-01-21T14:00:18.594539Z - 2024-01-21T17:13:08.569539Z | 40.0 Hz, 462800 samples
# CI.SYN..BHE | 2024-01-21T17:19:20.594538Z - 2024-01-21T17:31:20.569538Z | 40.0 Hz, 28800 samples
# CI.SYN..BHE | 2024-01-21T17:31:23.594539Z - 2024-01-21T23:59:59.994539Z | 40.0 Hz, 932657 samples
# 2 Trace(s) in Stream:
# CI.SYN..BHE | 2024-04-24T00:00:00.019538Z - 2024-04-24T17:40:07.569538Z | 40.0 Hz, 2544303 samples
# CI.SYN..BHE | 2024-04-24T17:40:15.594538Z - 2024-04-24T23:59:59.994538Z | 40.0 Hz, 911377 samples
# 2 Trace(s) in Stream:
# CI.SYN..BHE | 2024-05-09T00:00:00.019538Z - 2024-05-09T18:13:47.769538Z | 40.0 Hz, 2625111 samples
# CI.SYN..BHE | 2024-05-09T18:16:12.544538Z - 2024-05-09T23:59:59.994538Z | 40.0 Hz, 825099 samples
# 2 Trace(s) in Stream:
# CI.SYN..BHE | 2024-07-02T00:00:00.019538Z - 2024-07-02T22:49:53.569538Z | 40.0 Hz, 3287743 samples
# CI.SYN..BHE | 2024-07-02T22:50:02.269538Z - 2024-07-02T23:59:59.994538Z | 40.0 Hz, 167910 samples
# 3 Trace(s) in Stream:
# CI.SYN..BHE | 2024-07-28T00:00:00.019538Z - 2024-07-28T22:30:09.569538Z | 40.0 Hz, 3240383 samples
# CI.SYN..BHE | 2024-07-28T22:36:21.594538Z - 2024-07-28T22:48:46.569538Z | 40.0 Hz, 29800 samples
# CI.SYN..BHE | 2024-07-28T22:48:49.594541Z - 2024-07-28T23:59:59.994541Z | 40.0 Hz, 170817 samples
# 2 Trace(s) in Stream:
# CI.SYN..BHE | 2024-11-23T00:00:00.019538Z - 2024-11-23T09:52:37.569538Z | 40.0 Hz, 1422303 samples
# CI.SYN..BHE | 2024-11-23T09:58:50.594538Z - 2024-11-23T23:59:59.994538Z | 40.0 Hz, 2018777 samples
# 3 Trace(s) in Stream:
# CI.SYN..BHE | 2024-11-26T00:00:00.019538Z - 2024-11-26T17:35:45.569538Z | 40.0 Hz, 2533823 samples
# CI.SYN..BHE | 2024-11-26T17:35:53.069538Z - 2024-11-26T17:37:42.944538Z | 40.0 Hz, 4396 samples
# CI.SYN..BHE | 2024-11-26T17:40:13.694538Z - 2024-11-26T23:59:59.994538Z | 40.0 Hz, 911453 samples
# 2 Trace(s) in Stream:
# CI.SYN..BHE | 2024-11-28T00:00:00.019538Z - 2024-11-28T17:30:46.569538Z | 40.0 Hz, 2521863 samples
# CI.SYN..BHE | 2024-11-28T17:30:48.594541Z - 2024-11-28T23:59:59.994541Z | 40.0 Hz, 934057 samples
# 2 Trace(s) in Stream:
# CI.SYN..BHE | 2024-12-11T00:00:00.019538Z - 2024-12-11T23:56:31.444538Z | 40.0 Hz, 3447658 samples
# CI.SYN..BHE | 2024-12-11T23:56:59.169538Z - 2024-12-11T23:59:59.994538Z | 40.0 Hz, 7234 samples
# 34 Trace(s) in Stream:
#
# CI.SYN..BHN | 2024-01-01T00:00:00.019538Z - 2024-01-01T00:05:16.569538Z | 40.0 Hz, 12663 samples
# ...
# (32 other traces)
# ...
# CI.SYN..BHN | 2024-01-01T23:37:48.594541Z - 2024-01-01T23:55:11.569541Z | 40.0 Hz, 41720 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 47 Trace(s) in Stream:
#
# CI.SYN..BHN | 2024-01-02T00:01:23.594538Z - 2024-01-02T00:13:15.569538Z | 40.0 Hz, 28480 samples
# ...
# (45 other traces)
# ...
# CI.SYN..BHN | 2024-01-02T23:33:18.594541Z - 2024-01-02T23:59:59.994541Z | 40.0 Hz, 64057 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 33 Trace(s) in Stream:
#
# CI.SYN..BHN | 2024-01-03T00:00:00.019534Z - 2024-01-03T01:54:30.569534Z | 40.0 Hz, 274823 samples
# ...
# (31 other traces)
# ...
# CI.SYN..BHN | 2024-01-03T23:48:35.594538Z - 2024-01-03T23:59:59.994538Z | 40.0 Hz, 27377 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 38 Trace(s) in Stream:
#
# CI.SYN..BHN | 2024-01-04T00:00:00.019538Z - 2024-01-04T00:00:46.569538Z | 40.0 Hz, 1863 samples
# ...
# (36 other traces)
# ...
# CI.SYN..BHN | 2024-01-04T22:37:48.594541Z - 2024-01-04T23:59:59.994541Z | 40.0 Hz, 197257 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 45 Trace(s) in Stream:
#
# CI.SYN..BHN | 2024-01-05T00:00:00.019538Z - 2024-01-05T00:15:27.569538Z | 40.0 Hz, 37103 samples
# ...
# (43 other traces)
# ...
# CI.SYN..BHN | 2024-01-05T23:25:19.594539Z - 2024-01-05T23:59:59.994539Z | 40.0 Hz, 83217 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 57 Trace(s) in Stream:
#
# CI.SYN..BHN | 2024-01-06T00:00:00.019538Z - 2024-01-06T00:00:09.569538Z | 40.0 Hz, 383 samples
# ...
# (55 other traces)
# ...
# CI.SYN..BHN | 2024-01-06T23:53:18.594541Z - 2024-01-06T23:59:59.994541Z | 40.0 Hz, 16057 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 47 Trace(s) in Stream:
#
# CI.SYN..BHN | 2024-01-07T00:00:00.019878Z - 2024-01-07T02:09:08.569878Z | 40.0 Hz, 309943 samples
# ...
# (45 other traces)
# ...
# CI.SYN..BHN | 2024-01-07T23:08:12.594541Z - 2024-01-07T23:59:59.994541Z | 40.0 Hz, 124297 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 62 Trace(s) in Stream:
#
# CI.SYN..BHN | 2024-01-08T00:00:00.019538Z - 2024-01-08T01:30:32.569538Z | 40.0 Hz, 217303 samples
# ...
# (60 other traces)
# ...
# CI.SYN..BHN | 2024-01-08T23:13:49.594541Z - 2024-01-08T23:59:59.994541Z | 40.0 Hz, 110817 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 40 Trace(s) in Stream:
#
# CI.SYN..BHN | 2024-01-09T00:00:00.019538Z - 2024-01-09T01:24:46.569538Z | 40.0 Hz, 203463 samples
# ...
# (38 other traces)
# ...
# CI.SYN..BHN | 2024-01-09T23:13:48.594541Z - 2024-01-09T23:59:59.994541Z | 40.0 Hz, 110857 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 45 Trace(s) in Stream:
#
# CI.SYN..BHN | 2024-01-10T00:00:00.019536Z - 2024-01-10T00:01:50.569536Z | 40.0 Hz, 4423 samples
# ...
# (43 other traces)
# ...
# CI.SYN..B
samples
# 2 Trace(s) in Stream:
# CI.SYN..BHN | 2024-12-11T00:00:00.019538Z - 2024-12-11T23:56:33.269538Z | 40.0 Hz, 3447731 samples
# CI.SYN..BHN | 2024-12-11T23:57:01.794538Z - 2024-12-11T23:59:59.994538Z | 40.0 Hz, 7129 samples
# 34 Trace(s) in Stream:
#
# CI.SYN..BHZ | 2024-01-01T00:00:00.019538Z - 2024-01-01T00:05:16.569538Z | 40.0 Hz, 12663 samples
# ...
# (32 other traces)
# ...
# CI.SYN..BHZ | 2024-01-01T23:37:48.594541Z - 2024-01-01T23:55:11.569541Z | 40.0 Hz, 41720 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 47 Trace(s) in Stream:
#
# CI.SYN..BHZ | 2024-01-02T00:01:23.594538Z - 2024-01-02T00:13:15.569538Z | 40.0 Hz, 28480 samples
# ...
# (45 other traces)
# ...
# CI.SYN..BHZ | 2024-01-02T23:33:18.594541Z - 2024-01-02T23:59:59.994541Z | 40.0 Hz, 64057 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 33 Trace(s) in Stream:
#
# CI.SYN..BHZ | 2024-01-03T00:00:00.019534Z - 2024-01-03T01:54:30.569534Z | 40.0 Hz, 274823 samples
# ...
# (31 other traces)
# ...
# CI.SYN..BHZ | 2024-01-03T23:48:35.594538Z - 2024-01-03T23:59:59.994538Z | 40.0 Hz, 27377 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 38 Trace(s) in Stream:
#
# CI.SYN..BHZ | 2024-01-04T00:00:00.019538Z - 2024-01-04T00:00:46.569538Z | 40.0 Hz, 1863 samples
# ...
# (36 other traces)
# ...
# CI.SYN..BHZ | 2024-01-04T22:37:48.594541Z - 2024-01-04T23:59:59.994541Z | 40.0 Hz, 197257 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 45 Trace(s) in Stream:
#
# CI.SYN..BHZ | 2024-01-05T00:00:00.019538Z - 2024-01-05T00:15:27.569538Z | 40.0 Hz, 37103 samples
# ...
# (43 other traces)
# ...
# CI.SYN..BHZ | 2024-01-05T23:25:19.594539Z - 2024-01-05T23:59:59.994539Z | 40.0 Hz, 83217 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 57 Trace(s) in Stream:
#
# CI.SYN..BHZ | 2024-01-06T00:00:00.019538Z - 2024-01-06T00:00:09.569538Z | 40.0 Hz, 383 samples
# ...
# (55 other traces)
# ...
# CI.SYN..BHZ | 2024-01-06T23:53:18.594541Z - 2024-01-06T23:59:59.994541Z | 40.0 Hz, 16057 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 47 Trace(s) in Stream:
#
# CI.SYN..BHZ | 2024-01-07T00:00:00.019881Z - 2024-01-07T02:09:08.569881Z | 40.0 Hz, 309943 samples
# ...
# (45 other traces)
# ...
# CI.SYN..BHZ | 2024-01-07T23:08:12.594541Z - 2024-01-07T23:59:59.994541Z | 40.0 Hz, 124297 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 62 Trace(s) in Stream:
#
# CI.SYN..BHZ | 2024-01-08T00:00:00.019538Z - 2024-01-08T01:30:32.569538Z | 40.0 Hz, 217303 samples
# ...
# (60 other traces)
# ...
# CI.SYN..BHZ | 2024-01-08T23:13:49.594541Z - 2024-01-08T23:59:59.994541Z | 40.0 Hz, 110817 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 40 Trace(s) in Stream:
#
# CI.SYN..BHZ | 2024-01-09T00:00:00.019536Z - 2024-01-09T01:24:46.569536Z | 40.0 Hz, 203463 samples
# ...
# (38 other traces)
# ...
# CI.SYN..BHZ | 2024-01-09T23:13:48.594541Z - 2024-01-09T23:59:59.994541Z | 40.0 Hz, 110857 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 45 Trace(s) in Stream:
#
# CI.SYN..BHZ | 2024-01-10T00:00:00.019536Z - 2024-01-10T00:01:50.569536Z | 40.0 Hz, 4423 samples
# ...
# (43 other traces)
# ...
# CI.SYN..BHZ | 2024-01-10T23:53:38.594538Z - 2024-01-10T23:59:59.994538Z | 40.0 Hz, 15257 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 39 Trace(s) in Stream:
#
# CI.SYN..BHZ | 2024-01-11T00:00:00.019538Z - 2024-01-11T00:06:10.569538Z | 40.0 Hz, 14823 samples
# ...
# (37 other traces)
# ...
# CI.SYN..BHZ | 2024-01-11T23:50:26.594538Z - 2024-01-11T23:59:59.994538Z | 40.0 Hz, 22937 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 59 Trace(s) in Stream:
#
# CI.SYN..BHZ | 2024-01-12T00:00:00.019538Z - 2024-01-12T00:03:09.569538Z | 40.0 Hz, 7583 samples
# ...
# (57 other traces)
# ...
# CI.SYN..BHZ | 2024-01-12T23:30:48.594541Z - 2024-01-12T23:59:59.994541Z | 40.0 Hz, 70057 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 59 Trace(s) in Stream:
#
# CI.SYN..BHZ | 2024-01-13T00:00:00.019536Z - 2024-01-13T00:05:12.569536Z | 40.0 Hz, 12503 samples
# ...
# (57 other traces)
# ...
# CI.SYN..BHZ | 2024-01-13T23:50:09.594538Z - 2024-01-13T23:59:59.994538Z | 40.0 Hz, 23617 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 49 Trace(s) in Stream:
#
# CI.SYN..BHZ | 2024-01-14T00:00:00.019538Z - 2024-01-14T00:07:46.569538Z | 40.0 Hz, 18663 samples
# ...
# (47 other traces)
# ...
# CI.SYN..BHZ | 2024-01-14T23:54:48.594541Z - 2024-01-14T23:59:59.994541Z | 40.0 Hz, 12457 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 53 Trace(s) in Stream:
#
# CI.SYN..BHZ | 2024-01-15T00:00:00.019930Z - 2024-01-15T01:13:57.569930Z | 40.0 Hz, 177503 samples
# ...
# (51 other traces)
# ...
# CI.SYN..BHZ | 2024-01-15T23:47:48.594541Z - 2024-01-15T23:59:59.994541Z | 40.0 Hz, 29257 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 53 Trace(s) in Stream:
#
# CI.SYN..BHZ | 2024-01-16T00:00:00.019638Z - 2024-01-16T00:17:53.569638Z | 40.0 Hz, 42943 samples
# ...
# (51 other traces)
# ...
# CI.SYN..BHZ | 2024-01-16T23:28:42.594539Z - 2024-01-16T23:59:59.994539Z | 40.0 Hz, 75097 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 47 Trace(s) in Stream:
#
# CI.SYN..BHZ | 2024-01-17T00:00:00.019538Z - 2024-01-17T00:04:06.569538Z | 40.0 Hz, 9863 samples
# ...
# (45 other traces)
# ...
# CI.SYN..BHZ | 2024-01-17T23:22:49.594539Z - 2024-01-17T23:59:59.994539Z | 40.0 Hz, 89217 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 47 Trace(s) in Stream:
#
# CI.SYN..BHZ | 2024-01-18T00:00:00.019538Z - 2024-01-18T01:13:46.569538Z | 40.0 Hz, 177063 samples
# ...
# (45 other traces)
# ...
# CI.SYN..BHZ | 2024-01-18T23:43:48.594541Z - 2024-01-18T23:59:59.994541Z | 40.0 Hz, 38857 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 34 Trace(s) in Stream:
#
# CI.SYN..BHZ | 2024-01-19T00:00:00.019555Z - 2024-01-19T00:01:28.569555Z | 40.0 Hz, 3543 samples
# ...
# (32 other traces)
# ...
# CI.SYN..BHZ | 2024-01-19T23:35:18.594541Z - 2024-01-19T23:59:59.994541Z | 40.0 Hz, 59257 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 37 Trace(s) in Stream:
#
# CI.SYN..BHZ | 2024-01-20T00:00:00.019533Z - 2024-01-20T00:06:46.569533Z | 40.0 Hz, 16263 samples
# ...
# (35 other traces)
# ...
# CI.SYN..BHZ | 2024-01-20T23:54:19.594541Z - 2024-01-20T23:59:59.994541Z | 40.0 Hz, 13617 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 11 Trace(s) in Stream:
# CI.SYN..BHZ | 2024-01-21T00:00:00.019908Z - 2024-01-21T00:15:12.569908Z | 40.0 Hz, 36503 samples
# CI.SYN..BHZ | 2024-01-21T00:21:25.594538Z - 2024-01-21T00:53:40.569538Z | 40.0 Hz, 77400 samples
# CI.SYN..BHZ | 2024-01-21T00:53:43.594541Z - 2024-01-21T05:58:10.569541Z | 40.0 Hz, 730680 samples
# CI.SYN..BHZ | 2024-01-21T06:04:23.594538Z - 2024-01-21T06:18:40.569538Z | 40.0 Hz, 34280 samples
# CI.SYN..BHZ | 2024-01-21T06:18:43.594541Z - 2024-01-21T10:29:59.569541Z | 40.0 Hz, 603040 samples
# CI.SYN..BHZ | 2024-01-21T10:36:11.594538Z - 2024-01-21T10:48:16.569538Z | 40.0 Hz, 29000 samples
# CI.SYN..BHZ | 2024-01-21T10:48:19.594541Z - 2024-01-21T13:41:14.569541Z | 40.0 Hz, 415000 samples
# CI.SYN..BHZ | 2024-01-21T13:47:26.594538Z - 2024-01-21T14:00:15.569538Z | 40.0 Hz, 30760 samples
# CI.SYN..BHZ | 2024-01-21T14:00:18.594539Z - 2024-01-21T17:13:08.569539Z | 40.0 Hz, 462800 samples
# CI.SYN..BHZ | 2024-01-21T17:19:20.594538Z - 2024-01-21T17:31:20.569538Z | 40.0 Hz, 28800 samples
# CI.SYN..BHZ | 2024-01-21T17:31:23.594539Z - 2024-01-21T23:59:59.994539Z | 40.0 Hz, 932657 samples
# 2 Trace(s) in Stream:
# CI.SYN..BHZ | 2024-04-24T00:00:00.019538Z - 2024-04-24T17:40:07.569538Z | 40.0 Hz, 2544303 samples
# CI.SYN..BHZ | 2024-04-24T17:40:14.969538Z - 2024-04-24T23:59:59.994538Z | 40.0 Hz, 911402 samples
# 2 Trace(s) in Stream:
# CI.SYN..BHZ | 2024-05-09T00:00:00.019538Z - 2024-05-09T18:13:51.169538Z | 40.0 Hz, 2625247 samples
# CI.SYN..BHZ | 2024-05-09T18:16:12.744538Z - 2024-05-09T23:59:59.994538Z | 40.0 Hz, 825091 samples
# 2 Trace(s) in Stream:
# CI.SYN..BHZ | 2024-07-02T00:00:00.019538Z - 2024-07-02T22:49:53.569538Z | 40.0 Hz, 3287743 samples
# CI.SYN..BHZ | 2024-07-02T22:50:01.969538Z - 2024-07-02T23:59:59.994538Z | 40.0 Hz, 167922 samples
# 3 Trace(s) in Stream:
# CI.SYN..BHZ | 2024-07-28T00:00:00.019536Z - 2024-07-28T22:30:09.569536Z | 40.0 Hz, 3240383 samples
# CI.SYN..BHZ | 2024-07-28T22:36:21.594538Z - 2024-07-28T22:48:46.569538Z | 40.0 Hz, 29800 samples
# CI.SYN..BHZ | 2024-07-28T22:48:49.594541Z - 2024-07-28T23:59:59.994541Z | 40.0 Hz, 170817 samples
# 2 Trace(s) in Stream:
# CI.SYN..BHZ | 2024-11-23T00:00:00.019538Z - 2024-11-23T09:52:37.569538Z | 40.0 Hz, 1422303 samples
# CI.SYN..BHZ | 2024-11-23T09:58:50.594538Z - 2024-11-23T23:59:59.994538Z | 40.0 Hz, 2018777 samples
# 3 Trace(s) in Stream:
# CI.SYN..BHZ | 2024-11-26T00:00:00.019538Z - 2024-11-26T17:35:45.569538Z | 40.0 Hz, 2533823 samples
# CI.SYN..BHZ | 2024-11-26T17:35:51.769538Z - 2024-11-26T17:37:46.544538Z | 40.0 Hz, 4592 samples
# CI.SYN..BHZ | 2024-11-26T17:40:13.569538Z - 2024-11-26T23:59:59.994538Z | 40.0 Hz, 911458 samples
# 2 Trace(s) in Stream:
# CI.SYN..BHZ | 2024-11-28T00:00:00.019538Z - 2024-11-28T17:30:46.569538Z | 40.0 Hz, 2521863 samples
# CI.SYN..BHZ | 2024-11-28T17:30:48.594541Z - 2024-11-28T23:59:59.994541Z | 40.0 Hz, 934057 samples
# 2 Trace(s) in Stream:
# CI.SYN..BHZ | 2024-12-11T00:00:00.019538Z - 2024-12-11T23:56:29.369538Z | 40.0 Hz, 3447575 samples
# CI.SYN..BHZ | 2024-12-11T23:57:04.594538Z - 2024-12-11T23:59:59.994538Z | 40.0 Hz, 7017 samples

# %%
file_path = '01_Data/01_Seismic_Wave_Data/2024/SDD/BHZ/SDD_BHZ_2024-11-21.mseed'

stream = read(file_path)
stream.merge()
stream
# Out:
# 1 Trace(s) in Stream:
# CI.SDD..BHZ | 2024-11-21T00:00:00.019539Z - 2024-11-21T23:59:59.994539Z | 40.0 Hz, 3456000 samples (masked)
